# %% [markdown]
# <a href="https://colab.research.google.com/github/sameer0013/Data-science/blob/main/PCA/FailCaseOfPCA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import make_swiss_roll

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
X,colors = make_swiss_roll(n_samples = 800 , random_state = 123)

# %%
X
# Out:
# array([[  3.12587105,   8.1310993 , -10.83454657],
#        [  3.18795895,  11.67305128,   6.68827291],
#        [  5.77759401,   0.29701992,   3.68070284],
#        ...,
#        [ -1.02729165,   2.60294512,   7.91664979],
#        [ -4.34955147,  11.36246399,   7.18430167],
#        [  1.63060316,  13.27009924,   7.46280046]])

# %%
colors
# Out:
# array([11.27645641,  7.40918868,  6.85041356,  9.90840827, 11.49322427,
#         8.70007342, 13.95587378, 11.16675721,  9.24506537,  8.40800952,
#         7.94676558, 11.58352059,  8.84583501,  5.27483991,  8.46386771,
#        11.66783182,  6.43233302,  6.36598282,  9.72214265,  9.7247459 ,
#        10.69147715, 12.71809503, 11.54021956, 10.4711499 , 11.52125745,
#         7.75620503,  8.12216673,  6.86371925,  7.48057865, 10.65919885,
#         5.58045759,  8.79992623,  8.77317486,  9.36526141,  8.72574492,
#         7.65538167,  8.73065538, 13.13238348, 13.61088751,  9.44208822,
#        10.59300701,  5.80206668,  7.7027342 ,  8.62203392, 12.87716044,
#         7.07287519,  9.26487967, 14.00107113,  9.60842088, 10.4887838 ,
#         5.84928737, 12.50046755, 10.39609679,  9.84953391,  7.94286201,
#         7.57865989,  8.64273072, 11.13349742, 12.96337533,  9.52300618,
#        11.02052277, 10.23471089, 10.60196573, 11.07118348, 12.65127942,
# ...

# %%
fig = plt.figure(figsize=(9,9))
ax= fig.add_subplot(111,projection='3d')
ax.scatter(X[:,0],X[:,1],X[:,2],c= colors,cmap=plt.cm.rainbow)
plt.title('Swiss Roll')
plt.show()

# %%
from ctypes import alignment
import plotly.express as px
fig =px.scatter_3d(x=X[:,0],y=X[:,1],z=X[:,2], color = colors,opacity=0.7,size_max=29)
fig.update_layout(
    autosize=False,
    width=1700,
    height=700,
    
    )

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components = 2)

# %%
x_pca = pca.fit_transform(X)

# %%
plt.figure(figsize=(8,6))
plt.scatter(x_pca[:,0],x_pca[:,1],c=color,cmap=plt.cm.rainbow)
plt.title("Pca on swiss roll")
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.show()
